// %%
println("Start")
// Out:
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>90</td><td>application_1553135043314_0091</td><td>spark</td><td>idle</td><td><a target="_blank" href="https://sparkmlb.azurehdinsight.net/yarnui/hn/proxy/application_1553135043314_0091/">Link</a></td><td><a target="_blank" href="http://wn9-sparkm.q33fbvhpxvyuni0y4g53g3xvyg.bx.internal.cloudapp.net:30060/node/containerlogs/container_e04_1553135043314_0091_01_000001/livy">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// Start

// %% [markdown]
// Formats to change: <br>
// YYYY-MM-DD <br>
// DDMMYYYY <br>
// MMDDYYYY <br>

// %% [markdown]
// https://stackoverflow.com/questions/55614418/how-to-pass-multiple-date-formats-in-datetimeformatter-using-scala
